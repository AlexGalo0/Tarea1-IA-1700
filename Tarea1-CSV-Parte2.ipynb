# %%
import pandas as pd
firstData= pd.read_csv("first-data.csv") ## Creando nuestro Data-Frame desde un CSV

# %%
secondDataJSON=pd.read_json("second-data-json.json") ## Creando nuestro Data Frame desde un JSON

# %%
result = firstData.merge(secondDataJSON,how='outer') ##Mergin Outer para ambos DataFrames
result
# Out:
#          Alumno Codigo                         Asignatura  UV  Seccion   Año  \
# 0   20181002352  EG011                    ESPAÑOL GENERAL   4      904  2018
# 1   20181002352  BI130       EDUCACION AMBIENTAL OPTATIVA   3      800  2018
# 2   20181002352  MM110                       MATEMATICA I   5     1001  2018
# 3   20181002352  IS110        INTROD.A LA ING.EN SISTEMAS   3     1101  2018
# 4   20181002352  HH101               HISTORIA DE HONDURAS   4      704  2018
# ..          ...    ...                                ...  ..      ...   ...
# 77  20171004928  IM315                MECANICA DE FLUIDOS   3     1800  2021
# 78  20171004928  II336  PLANEACION Y CONTROL DE PROYECTOS   3     1800  2021
# 79  20171004928  IM313           MECANICA DE MATERIALES I   5     1700  2021
# 80  20171004928  DQ101                           DIBUJO I   2     1302  2021
# 81  20171004928  IM328                    TERMODINAMICA I   3      800  2021
#
#     Periodo  Calificacion
# ...

# %%
result.Calificacion.mean() ## Notas Promedios de los 2 alumnos
# Out:
# 74.03658536585365
