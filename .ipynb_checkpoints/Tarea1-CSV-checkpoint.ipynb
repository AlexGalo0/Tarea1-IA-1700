# %%
import pandas as pd
firstData=pd.read_csv("first-data.csv")
firstData
# Out:
#     Codigo                         Asignatura  UV  Seccion   Año  Periodo  \
# 0    EG011                    ESPAÑOL GENERAL   4      904  2018        1
# 1    BI130       EDUCACION AMBIENTAL OPTATIVA   3      800  2018        1
# 2    MM110                       MATEMATICA I   5     1001  2018        1
# 3    IS110        INTROD.A LA ING.EN SISTEMAS   3     1101  2018        1
# 4    HH101               HISTORIA DE HONDURAS   4      704  2018        1
# 5    AN112      INTRODUCCION AL SISTEMA SOLAR   3     1000  2018        2
# 6    FF101                        FILOSOFIA I   4     1705  2018        2
# 7    EO025         REDACCION GENERAL OPTATIVA   3     1103  2018        2
# 8    MM111          GEOMETRIA Y TRIGONOMETRIA   5     1201  2018        2
# 9    MM111          GEOMETRIA Y TRIGONOMETRIA   5     1401  2018        3
# 10   MM211                VECTORES Y MATRICES   3     1000  2018        3
# 11   MM201                          CALCULO I   5     1400  2019        1
# ...

# %%
import pandas as pd
secondData=pd.read_csv("second-data.csv")
secondData
# Out:
#    Codigo                         Asignatura  UV  Seccion   Año  Periodo  \
# 0   RR176                   GIMNASIA GENERAL   5     1100  2017        1
# 1   IN101                           INGLES I   4      801  2017        1
# 2   SC101                         SOCIOLOGIA   4      703  2017        1
# 3   EO025         REDACCION GENERAL OPTATIVA   3     1200  2017        1
# 4   EG011                    ESPAÑOL GENERAL   4      807  2017        2
# 5   CP101                 CIENCIAS POLITICAS   4     1100  2017        2
# 6   HH101               HISTORIA DE HONDURAS   4     1002  2017        2
# 7   FF101                        FILOSOFIA I   4      700  2017        2
# 8   IM135   INTROD. A LA INGENIERIA MECANICA   2     1000  2018        1
# 9   MM110                       MATEMATICA I   5     1200  2018        1
# 10  BI130       EDUCACION AMBIENTAL OPTATIVA   3     1300  2018        1
# 11  MM111          GEOMETRIA Y TRIGONOMETRIA   5      700  2018        1
# ...

# %%
firstData.columns
# Out:
# Index(['Codigo', 'Asignatura', 'UV', 'Seccion', 'Año', 'Periodo',
#        'Calificacion', 'OBS'],
#       dtype='object')

# %%
firstData.Calificacion
# Out:
# 0      74
# 1      70
# 2      65
# 3      52
# 4      65
# 5      74
# 6      85
# 7      68
# 8      46
# 9      71
# 10     49
# 11     63
# 12     68
# 13     58
# 14     65
# 15     68
# 16     73
# 17     73
# 18     93
# 19     89
# 20     85
# 21     97
# 22    100
# 23     78
# 24     77
# 25     86
# 26     68
# 27     74
# 28     97
# 29     73
# 30     82
# 31     78
# 32     67
# 33     84
# 34     65
# 35     68
# 36     73
# 37     95
# 38     65
# 39     68
# 40     13
# 41     91
# 42     82
# 43     88
# Name: Calificacion, dtype: int64

# %%
firstData.Calificacion.max() ## La nota mas alta del primer alumno
# Out:
# 100

# %%
firstData.Calificacion.min() ## La nota mas baja del primer alumno
# Out:
# 13

# %%
secondData.Calificacion.max() ## La nota mas alta del segundo alumno
# Out:
# 95

# %%
secondData.Calificacion.min() ## La nota mas baja del segundo alumno
# Out:
# 43

# %%
firstData.Calificacion.mean() ##Promedio de notas para el primer alumno
# Out:
# 73.25

# %%
secondData.Calificacion.mean() ##Promedio de notas para el segundo alumno
# Out:
# 74.94736842105263

# %%
firstData[firstData.Calificacion<65] ##Cantidad de Clases Reprobadas para el primer alumno
# Out:
#    Codigo                   Asignatura  UV  Seccion   Año  Periodo  \
# 3   IS110  INTROD.A LA ING.EN SISTEMAS   3     1101  2018        1
# 8   MM111    GEOMETRIA Y TRIGONOMETRIA   5     1201  2018        2
# 10  MM211          VECTORES Y MATRICES   3     1000  2018        3
# 11  MM201                    CALCULO I   5     1400  2019        1
# 13  MM211          VECTORES Y MATRICES   3     1500  2019        1
# 40  IS601             BASE DE DATOS II   4      900  2022        1
#
#     Calificacion  OBS
# 3             52  RPB
# 8             46  RPB
# 10            49  RPB
# 11            63  RPB
# 13            58  RPB
# 40            13  ABD

# %%
secondData[secondData.Calificacion<65] ##Cantidad de Clases Reprobadas para el segundo alumno
# Out:
#    Codigo                 Asignatura  UV  Seccion   Año  Periodo  Calificacion
# 9   MM110               MATEMATICA I   5     1200  2018        1            43
# 11  MM111  GEOMETRIA Y TRIGONOMETRIA   5      700  2018        1            50
# 14  MM111  GEOMETRIA Y TRIGONOMETRIA   5     1200  2018        2            44
# 16  MM201                  CALCULO I   5     1400  2019        1            60
# 18  MM211        VECTORES Y MATRICES   3     1500  2019        1            48
# 19  MM201                  CALCULO I   5      600  2019        2            63

# %%
frames=[firstData,secondData]

# %%
result= pd.concat(frames) ##concat de los dos dataframes
result
# Out:
#    Codigo                         Asignatura  UV  Seccion   Año  Periodo  \
# 0   EG011                    ESPAÑOL GENERAL   4      904  2018        1
# 1   BI130       EDUCACION AMBIENTAL OPTATIVA   3      800  2018        1
# 2   MM110                       MATEMATICA I   5     1001  2018        1
# 3   IS110        INTROD.A LA ING.EN SISTEMAS   3     1101  2018        1
# 4   HH101               HISTORIA DE HONDURAS   4      704  2018        1
# ..    ...                                ...  ..      ...   ...      ...
# 33  IM315                MECANICA DE FLUIDOS   3     1800  2021        1
# 34  II336  PLANEACION Y CONTROL DE PROYECTOS   3     1800  2021        2
# 35  IM313           MECANICA DE MATERIALES I   5     1700  2021        2
# 36  DQ101                           DIBUJO I   2     1302  2021        2
# 37  IM328                    TERMODINAMICA I   3      800  2021        2
#
#     Calificacion  OBS
# 0             74  APR
# 1             70  APR
# ...

# %%
result.Calificacion.mean()  ##Nota promedio de los 2 alumnos
# Out:
# 74.03658536585365
